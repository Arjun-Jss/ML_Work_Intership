# %% [markdown]
# EDA (Exploratory Data Analysis )

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df['Profit'].max()
# Out:
# 192261.83

# %%
df['Profit'].min()
# Out:
# 14681.4

# %%
Profit_numeric = df.select_dtypes(include=['int64','float64'])
Profit_numeric
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95
# 11  100671.96        91790.61        249744.55  144259.40
# 12   93863.75       127320.38        249839.44  141585.52
# 13   91992.39       135495.07        252664.93  134307.35
# 14  119943.24       156547.42        256512.92  132602.65
# ...

# %%
df.corr()['Profit']
# Out:
# R&D Spend          0.972900
# Administration     0.200717
# Marketing Spend    0.747766
# Profit             1.000000
# Name: Profit, dtype: float64

# %%
Profit_numeric = Profit_numeric.drop(['R&D Spend','Administration'],axis =1)
Profit_numeric
# Out:
#     Marketing Spend     Profit
# 0         471784.10  192261.83
# 1         443898.53  191792.06
# 2         407934.54  191050.39
# 3         383199.62  182901.99
# 4         366168.42  166187.94
# 5         362861.36  156991.12
# 6         127716.82  156122.51
# 7         323876.68  155752.60
# 8         311613.29  152211.77
# 9         304981.62  149759.96
# 10        229160.95  146121.95
# 11        249744.55  144259.40
# 12        249839.44  141585.52
# 13        252664.93  134307.35
# 14        256512.92  132602.65
# 15        261776.23  129917.04
# 16        264346.06  126992.93
# 17        282574.31  125370.37
# 18        294919.57  124266.90
# 19             0.00  122776.86
# 20        298664.47  118474.03
# 21        299737.29  111313.02
# 22        303319.26  110352.25
# 23        304768.73  108733.99
# 24        140574.81  108552.04
# 25        137962.62  107404.34
# 26        134050.07  105733.54
# 27        353183.81  105008.31
# 28        118148.20  103282.38
# ...

# %%
x = df.iloc[:,0:3].values
x
# Out:
# array([[165349.2 , 136897.8 , 471784.1 ],
#        [162597.7 , 151377.59, 443898.53],
#        [153441.51, 101145.55, 407934.54],
#        [144372.41, 118671.85, 383199.62],
#        [142107.34,  91391.77, 366168.42],
#        [131876.9 ,  99814.71, 362861.36],
#        [134615.46, 147198.87, 127716.82],
#        [130298.13, 145530.06, 323876.68],
#        [120542.52, 148718.95, 311613.29],
#        [123334.88, 108679.17, 304981.62],
#        [101913.08, 110594.11, 229160.95],
#        [100671.96,  91790.61, 249744.55],
#        [ 93863.75, 127320.38, 249839.44],
#        [ 91992.39, 135495.07, 252664.93],
#        [119943.24, 156547.42, 256512.92],
#        [114523.61, 122616.84, 261776.23],
#        [ 78013.11, 121597.55, 264346.06],
#        [ 94657.16, 145077.58, 282574.31],
#        [ 91749.16, 114175.79, 294919.57],
#        [ 86419.7 , 153514.11,      0.  ],
#        [ 76253.86, 113867.3 , 298664.47],
#        [ 78389.47, 153773.43, 299737.29],
# ...

# %%
x.ndim
# Out:
# 2

# %%
y = df.iloc[:,4].values
y
# Out:
# array([192261.83, 191792.06, 191050.39, 182901.99, 166187.94, 156991.12,
#        156122.51, 155752.6 , 152211.77, 149759.96, 146121.95, 144259.4 ,
#        141585.52, 134307.35, 132602.65, 129917.04, 126992.93, 125370.37,
#        124266.9 , 122776.86, 118474.03, 111313.02, 110352.25, 108733.99,
#        108552.04, 107404.34, 105733.54, 105008.31, 103282.38, 101004.64,
#         99937.59,  97483.56,  97427.84,  96778.92,  96712.8 ,  96479.51,
#         90708.19,  89949.14,  81229.06,  81005.76,  78239.91,  77798.83,
#         71498.49,  69758.98,  65200.33,  64926.08,  49490.75,  42559.73,
#         35673.41,  14681.4 ])

# %%
y.ndim
# Out:
# 1

# %% [markdown]
# Matplotlib

# %%
from sklearn.model_selection import train_test_split 
x_train,x_test,y_train,y_test = train_test_split(x,y)

# %%
Profit_numeric.shape
# Out:
# (50, 2)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (37, 3)
# (13, 3)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (37,)
# (13,)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Actual And Predict

# %%
y_pred = model.predict(x_test)
y_pred
# Out:
# array([146799.73373251, 101129.0365305 ,  99286.21974704,  72147.41892532,
#         68551.40365223, 174647.42692866, 183757.1008668 , 149543.84968026,
#         57971.29063999, 115708.45361207,  73080.65427259,  45157.43415442,
#         48558.93753647])

# %%
y_test
# Out:
# array([129917.04, 107404.34,  99937.59,  90708.19,  71498.49, 182901.99,
#        191050.39, 132602.65,  69758.98, 126992.93,  77798.83,  64926.08,
#         35673.41])

# %%
from sklearn.metrics import r2_score 
r2_score(y_test,y_pred)
# Out:
# 0.922951406451178

# %%
import matplotlib.pyplot as plt
plt.scatter(y_pred,y_test)
#plt.plot(y_pred,y_test)

# %%
df1 = pd.DataFrame({'Actual':y_test,'Predicted':y_pred})
df1
# Out:
#        Actual      Predicted
# 0   129917.04  146799.733733
# 1   107404.34  101129.036531
# 2    99937.59   99286.219747
# 3    90708.19   72147.418925
# 4    71498.49   68551.403652
# 5   182901.99  174647.426929
# 6   191050.39  183757.100867
# 7   132602.65  149543.849680
# 8    69758.98   57971.290640
# 9   126992.93  115708.453612
# 10   77798.83   73080.654273
# 11   64926.08   45157.434154
# 12   35673.41   48558.937536

# %%
df1.plot(figsize = (11,12))
plt.show()

# %%
df1.plot(figsize = (11,12),kind = 'bar')
plt.show()

# %% [markdown]
# SDV (Seaborn Data Visualization )

# %%
#Regression plot
#seaborn - based on the matplotlib
import seaborn as sns

# %%
sns.distplot(df['Profit'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Profit'],hist = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['Profit'], kde = False)#kde - kernel density estimate
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(15,12))
plt.subplot(1,2,1)
sns.scatterplot(x = 'Actual', y = 'Predicted', data = df1)
plt.subplot(1,2,2)
sns.regplot(x = 'Actual', y = 'Predicted', data = df1,color= 'purple')#Regression plot for Multi Linear
